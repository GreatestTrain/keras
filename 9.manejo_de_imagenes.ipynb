# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
im = io.imread('./input/Mara.jpeg')

# %%
_ = 0
aux_dim = np.zeros(im.shape, dtype=np.uint8)
aux_dim[:,:,_] = im[:,:,_]

# %%
aux_dim[:,:,0]
# Out:
# array([[ 98., 103.,  98., ..., 181., 180., 180.],
#        [ 97., 103.,  98., ..., 181., 180., 180.],
#        [ 96., 103., 101., ..., 180., 180., 180.],
#        ...,
#        [ 68.,  65.,  81., ...,  73., 117., 108.],
#        [ 75., 103.,  68., ...,  98.,  33.,  69.],
#        [ 90.,  87.,  50., ...,  93.,  71.,  59.]])

# %%
fig, ax = plt.subplots(1,3, figsize=(9,4),
                       subplot_kw={'xticks': [], 'yticks': []})
for _, axe in enumerate(ax.flatten()[:3]):
    aux_dim = np.zeros(im.shape, dtype=np.uint8)
    aux_dim[:,:,_] = im[:,:,_]
    axe.imshow(aux_dim)
